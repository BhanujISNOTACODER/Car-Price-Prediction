# %%
import pandas as pd
import numpy as np

# %%
cars = pd.read_csv('../dataset/true_car_listings.csv')
cars
# Out:
#         Price  Year  Mileage              City State                Vin  \
# 0        8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...       ...   ...      ...               ...   ...                ...
# 852117  63215  2017        9       Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016    28941      Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017     3005       San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017     2502          New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model
# 0       Acura    ILX6-Speed
# 1       Acura    ILX5-Speed
# ...

# %%
cars.sample(5)
# Out:
#         Price  Year  Mileage          City State                Vin      Make  \
# 525924  14000  2016    13809     Rock Hill    SC  KNADM5A36G6686237       Kia
# 194180   4995  2007    96000  Newport News    VA  1C3LC56K17N562694  Chrysler
# 816777  29997  2015    33388   D'Iberville    MS  JTEZU5JR8F5104040    Toyota
# 820203  41498  2015    24930   Saint Cloud    FL  5TFDW5F11FX444937    Toyota
# 239577  10999  2015    43590        Peoria    AZ  3FA6P0H75FR244894      Ford
#
#              Model
# 525924   Rio5-door
# 194180     Sebring
# 816777  4Runner4x2
# 820203      Tundra
# 239577    FusionSE

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852122 entries, 0 to 852121
# Data columns (total 8 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Price    852122 non-null  int64
#  1   Year     852122 non-null  int64
#  2   Mileage  852122 non-null  int64
#  3   City     852122 non-null  object
#  4   State    852122 non-null  object
#  5   Vin      852122 non-null  object
#  6   Make     852122 non-null  object
#  7   Model    852122 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 52.0+ MB

# %%
cars.drop(columns=["Vin","State","City"],inplace=True)

# %%
np.set_printoptions(threshold=np.inf)
cars["Model"].unique()
# Out:
# array(['ILX6-Speed', 'ILX5-Speed', 'ILXAutomatic', 'TSXAutomatic',
#        'TSXSpecial', 'TSX5-Speed', 'TSX4dr', 'TSX', 'ILX4dr',
#        'ILXAcuraWatch', 'ILXHybrid', 'TSXManual', 'TSXPremium',
#        'ILXPremium', 'ILXTechnology', 'TL4dr', 'TL2WD', 'TLBase',
#        'TLSpecial', 'TLAutomatic', 'TSXV6', 'TLwith', 'TLSH-AWD',
#        'TLType-S', 'TLManual', 'RDXFWD', 'TLXFWD', 'RDX4WD', 'RDXAWD',
#        'RSXAutomatic', 'RDXwith', 'RSXType-S',
#        'RDX*1-OWNER*LTHR*ROOF*BACK-UP*TECH', 'RSXManual', 'SLX4WD',
#        'RDXBase', 'RLAutomatic', 'CLAutomatic', 'TLXSH-AWD', 'CLType-S',
#        'MDX4WD', 'ZDXAWD', 'RL4dr', 'MDXAWD', 'TL3.2', 'IntegraGS',
#        'MDXACURA', 'MDXBase', 'IntegraLS', 'MDXFWD', 'ZDXBase',
#        'CLManual', 'MDXwith', 'RLXwith', 'RLXBase', 'MDXSH-AWD',
#        'RLXAutomatic', 'IntegraRS', 'MDXAdvance', 'RLXHybrid', 'MDX3.5L',
#        'MDXSport', 'NSXManual', 'NSXCoupe', 'Romeo', 'General', 'Martin',
# ...

# %%
cars.Model = cars.Model.apply(lambda X:X.replace("-",""))

# %%
cars.Model = cars.Model.apply(lambda X:X.replace("+",""))

# %%
cars.Model = cars.Model.apply(lambda X:X.replace(".",""))

# %%
cars.Model = cars.Model.apply(lambda X:X.replace("*",""))

# %%
cars=cars.sample(10000)

# %%
# Out:
#        index  Price  Year  Mileage       Make           Model
# 0     273094  19397  2016    40450       Ford       EscapeFWD
# 1     754808  16998  2015     7066     Toyota        CorollaS
# 2     175496  38970  2015    59651  Chevrolet     Suburban2WD
# 3      20279  33999  2015    30215       Audi           Q730T
# 4     398089  13999  2010    66214      Honda          Accord
# ...      ...    ...   ...      ...        ...             ...
# 9995   87517  17233  2017    28178  Chevrolet        MalibuLT
# 9996  232057  27995  2014    46090      Dodge  DurangoLimited
# 9997  808528   9500  2013   110239     Toyota   TacomaRegular
# 9998  346969  37995  2014    56179       Ford         F1504WD
# 9999  331456  31245  2016    29446       Ford     Explorer4WD
#
# [10000 rows x 6 columns]

# %%
cars.drop(columns=['index'])
# Out:
#       Price  Year  Mileage       Make           Model
# 0     19397  2016    40450       Ford       EscapeFWD
# 1     16998  2015     7066     Toyota        CorollaS
# 2     38970  2015    59651  Chevrolet     Suburban2WD
# 3     33999  2015    30215       Audi           Q730T
# 4     13999  2010    66214      Honda          Accord
# ...     ...   ...      ...        ...             ...
# 9995  17233  2017    28178  Chevrolet        MalibuLT
# 9996  27995  2014    46090      Dodge  DurangoLimited
# 9997   9500  2013   110239     Toyota   TacomaRegular
# 9998  37995  2014    56179       Ford         F1504WD
# 9999  31245  2016    29446       Ford     Explorer4WD
#
# [10000 rows x 5 columns]

# %%
cars
# Out:
#        index  Price  Year  Mileage       Make           Model
# 0     273094  19397  2016    40450       Ford       EscapeFWD
# 1     754808  16998  2015     7066     Toyota        CorollaS
# 2     175496  38970  2015    59651  Chevrolet     Suburban2WD
# 3      20279  33999  2015    30215       Audi           Q730T
# 4     398089  13999  2010    66214      Honda          Accord
# ...      ...    ...   ...      ...        ...             ...
# 9995   87517  17233  2017    28178  Chevrolet        MalibuLT
# 9996  232057  27995  2014    46090      Dodge  DurangoLimited
# 9997  808528   9500  2013   110239     Toyota   TacomaRegular
# 9998  346969  37995  2014    56179       Ford         F1504WD
# 9999  331456  31245  2016    29446       Ford     Explorer4WD
#
# [10000 rows x 6 columns]

# %%
cars.describe()
# Out:
#               Price         Year        Mileage
# count   9735.000000  9735.000000    9735.000000
# mean   20089.215100  2013.235131   53240.725218
# std     9542.772384     3.402201   40980.702779
# min     1689.000000  1997.000000       5.000000
# 25%    12995.000000  2012.000000   24604.500000
# 50%    17998.000000  2014.000000   41008.000000
# 75%    25995.000000  2016.000000   72859.000000
# max    49998.000000  2018.000000  400483.000000

# %%
cars = cars[cars.Price<50000]

# %%
cars
# Out:
#       Price  Year  Mileage       Make           Model
# 0     19397  2016    40450       Ford       EscapeFWD
# 1     16998  2015     7066     Toyota        CorollaS
# 2     38970  2015    59651  Chevrolet     Suburban2WD
# 3     33999  2015    30215       Audi           Q730T
# 4     13999  2010    66214      Honda          Accord
# ...     ...   ...      ...        ...             ...
# 9995  17233  2017    28178  Chevrolet        MalibuLT
# 9996  27995  2014    46090      Dodge  DurangoLimited
# 9997   9500  2013   110239     Toyota   TacomaRegular
# 9998  37995  2014    56179       Ford         F1504WD
# 9999  31245  2016    29446       Ford     Explorer4WD
#
# [9735 rows x 5 columns]

# %%
cars.reset_index(drop=True)
# Out:
#       Price  Year  Mileage       Make           Model
# 0     19397  2016    40450       Ford       EscapeFWD
# 1     16998  2015     7066     Toyota        CorollaS
# 2     38970  2015    59651  Chevrolet     Suburban2WD
# 3     33999  2015    30215       Audi           Q730T
# 4     13999  2010    66214      Honda          Accord
# ...     ...   ...      ...        ...             ...
# 9730  17233  2017    28178  Chevrolet        MalibuLT
# 9731  27995  2014    46090      Dodge  DurangoLimited
# 9732   9500  2013   110239     Toyota   TacomaRegular
# 9733  37995  2014    56179       Ford         F1504WD
# 9734  31245  2016    29446       Ford     Explorer4WD
#
# [9735 rows x 5 columns]

# %%
cars.drop(columns=['index'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 cars.drop(columns=['index'],inplace=True)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
# ...

# %%
cars
# Out:
#       Price  Year  Mileage       Make           Model
# 0     19397  2016    40450       Ford       EscapeFWD
# 1     16998  2015     7066     Toyota        CorollaS
# 2     38970  2015    59651  Chevrolet     Suburban2WD
# 3     33999  2015    30215       Audi           Q730T
# 4     13999  2010    66214      Honda          Accord
# ...     ...   ...      ...        ...             ...
# 9995  17233  2017    28178  Chevrolet        MalibuLT
# 9996  27995  2014    46090      Dodge  DurangoLimited
# 9997   9500  2013   110239     Toyota   TacomaRegular
# 9998  37995  2014    56179       Ford         F1504WD
# 9999  31245  2016    29446       Ford     Explorer4WD
#
# [9735 rows x 5 columns]

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9735 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Price    9735 non-null   int64
#  1   Year     9735 non-null   int64
#  2   Mileage  9735 non-null   int64
#  3   Make     9735 non-null   object
#  4   Model    9735 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 456.3+ KB

# %% [markdown]
# ## Model

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
cars.Make = cars.Make.apply(lambda X:X.replace("-",""))

# %%
inp = cars[['Year','Mileage','Make','Model']]
op = cars[['Price']]

# %%
inp
# Out:
#       Year  Mileage       Make           Model
# 0     2016    40450       Ford       EscapeFWD
# 1     2015     7066     Toyota        CorollaS
# 2     2015    59651  Chevrolet     Suburban2WD
# 3     2015    30215       Audi           Q730T
# 4     2010    66214      Honda          Accord
# ...    ...      ...        ...             ...
# 9995  2017    28178  Chevrolet        MalibuLT
# 9996  2014    46090      Dodge  DurangoLimited
# 9997  2013   110239     Toyota   TacomaRegular
# 9998  2014    56179       Ford         F1504WD
# 9999  2016    29446       Ford     Explorer4WD
#
# [9735 rows x 4 columns]

# %%
op
# Out:
#       Price
# 0     19397
# 1     16998
# 2     38970
# 3     33999
# 4     13999
# ...     ...
# 9995  17233
# 9996  27995
# 9997   9500
# 9998  37995
# 9999  31245
#
# [9735 rows x 1 columns]

# %%
ohe = OneHotEncoder()
ohe.fit(inp[["Year","Make","Model"]])
ohe.categories_
# Out:
# [array([1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#         2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
#        dtype=int64),
#  array(['AM', 'Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#         'Chrysler', 'Dodge', 'FIAT', 'Ford', 'GMC', 'HUMMER', 'Honda',
#         'Hyundai', 'INFINITI', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Land',
#         'Lexus', 'Lincoln', 'Lotus', 'MINI', 'Maserati', 'Mazda',
#         'MercedesBenz', 'Mercury', 'Mitsubishi', 'Nissan', 'Oldsmobile',
#         'Plymouth', 'Pontiac', 'Porsche', 'Ram', 'Saab', 'Saturn', 'Scion',
#         'Subaru', 'Suzuki', 'Tesla', 'Toyota', 'Volkswagen', 'Volvo',
#         'smart'], dtype=object),
#  array(['1', '15002WD', '15004WD', '1500Big', '1500Express',
#         '1500Express,', '1500HFE', '1500Laramie', '1500Laramie,',
#         '1500Lone', '1500Longhorn,', '1500Outdoorsman,', '1500Rebel',
# ...

# %%
col_transform = make_column_transformer((OneHotEncoder(categories=ohe.categories_),["Year","Make",'Model']),remainder="passthrough")

# %%
lr = LinearRegression()
pipe = make_pipeline(col_transform,lr)

# %%
inp_train,inp_test,op_train,op_test = train_test_split(inp,op,test_size=0.2)

# %%
pipe.fit(inp_train,op_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array([1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
#       dtype=int64),
#                                                                             array(['AM', 'Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge',...
#        'YarisBase', 'YarisSedan', 'Yukon', 'Yukon2WD', 'Yukon4WD',
#        'Yukon4dr', 'YukonAWD', 'Z42dr', 'ZDXAWD', 'allroad20T', 'cubeS',
#        'fortwoCoupe', 'fortwoPassion', 'fortwopure', 'i2902WD',
#        'i3Hatchback', 'iA4dr', 'iAAutomatic', 'iMManual', 'iQ3dr',
#        'iQHatchback', 'tC2dr', 'tC3dr', 'tCAutomatic', 'xA4dr', 'xB5dr',
# ...

# %%
pred = pipe.predict(inp_test)

# %%
from sklearn.metrics import r2_score

# %%
scores=[]
for i in range(1000):   
    inp_train,inp_test,op_train,op_test = train_test_split(inp,op,test_size=0.2,random_state=541)
    pipe.fit(inp_train,op_train)
    pred = pipe.predict(inp_test)
    r2 = r2_score(op_test,pred)
    scores.append(r2)
scores
# Out:
# [0.6314770702245168,
#  0.5638229483250321,
#  0.6243089265617955,
#  0.6118398789287713,
#  0.5726848847733845,
#  0.6037863658617055,
#  0.5922268532330877,
#  0.6273308956514903,
#  0.5661894378807295,
#  0.6067128680022325,
#  0.6064833512852368,
#  0.625423257271555,
#  0.6137453544088833,
#  0.5700137764473099,
#  0.5783964508524844,
#  0.5547351988234088,
#  0.5658245758271878,
#  0.5628995543020308,
#  0.6380779199194022,
#  0.6231314325104051,
#  0.6271878771938599,
#  0.6133827107505556,
#  0.6058571568233371,
#  0.5658435038630374,
#  0.6240077322226208,
#  0.611575785554834,
#  0.5561161423269942,
#  0.6071862760755251,
#  0.633472482825784,
#  0.5727623822891068,
#  0.5780808262516022,
#  0.6195453511707387,
#  0.5540777484953963,
#  0.6420121758590773,
#  0.619998693043657,
#  0.5613511793722786,
#  0.6055361004181374,
#  0.6029660860110904,
#  0.6180392767184455,
#  0.6091708436275877,
#  0.6204271465236174,
#  0.5987383822211656,
#  0.584751806822289,
# ...

# %%
np.argmax(scores)
# Out:
# 541

# %%
inp_train,inp_test,op_train,op_test = train_test_split(inp,op,test_size=0.2,random_state=541)
pipe.fit(inp_train,op_train)
pred = pipe.predict(inp_test)
pred
# Out:
# array([[ 2.00927543e+04],
#        [ 2.76532257e+04],
#        [ 2.08863466e+04],
#        [ 1.26000140e+04],
#        [ 2.11754301e+04],
#        [ 1.29456361e+04],
#        [ 2.61988511e+04],
#        [ 1.72743691e+04],
#        [ 2.33171864e+04],
#        [ 3.55633458e+04],
#        [ 1.67870180e+04],
#        [ 1.88384917e+04],
#        [ 1.86059528e+04],
#        [ 1.84364862e+04],
#        [ 1.96673021e+04],
#        [ 2.00021647e+04],
#        [ 2.17467407e+04],
#        [ 1.63948829e+04],
#        [ 2.22129499e+04],
#        [ 1.85442097e+04],
#        [ 4.45722098e+03],
#        [ 1.51980648e+04],
#        [ 1.62852226e+04],
#        [ 1.47662220e+04],
#        [ 2.98731246e+04],
#        [ 1.21303863e+04],
#        [ 1.51609306e+04],
#        [ 1.12795435e+04],
#        [ 2.13688064e+04],
#        [ 2.81438840e+04],
#        [ 1.99012173e+04],
#        [ 4.74593331e+03],
#        [ 1.01333127e+04],
#        [ 1.34894928e+04],
#        [ 2.28785900e+04],
# ...

# %%
custom_test=pd.DataFrame([[2016,40450,"Ford","EscapeFWD"]],columns=["Year","Mileage","Make","Model"])

# %%
pipe.predict(custom_test)
# Out:
# array([[17215.62924125]])

# %%
import pickle
pickle.dump(pipe,open('model.pkl','wb'))
